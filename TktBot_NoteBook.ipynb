# %%
import random
from santorinai.board import Board
from santorinai.pawn import Pawn
from santorinai.player import Player
from santorinai.player_examples.basic_player import BasicPlayer

# %% [markdown]
# Basic Rules

# %%
def movesPlayer(board, players, x, y):
    z = board[x][y]
    moves = []
    for i in range(-1, 2):
        for j in range(-1, 2):
            if i == 0 and j == 0:
                continue
            if x+i < 0 or x+i >= len(board):
                continue
            if y+j < 0 or y+j >= len(board):
                continue
            if board[x+i][y+j] - z < 2 and board[x+i][y+j] < 4 and (x+i, y+j) not in players:
                moves.append((x+i, y+j))
    return moves

# %%
def constructsPlayer(board, players, x, y):
    places = []
    for i in range(-1, 2):
        for j in range(-1, 2):
            if i == 0 and j == 0:
                continue
            if x+i < 0 or x+i >= len(board):
                continue
            if y+j < 0 or y+j >= len(board):
                continue
            if board[x+i][y+j] < 4 and (x+i, y+j) not in players:
                places.append((x+i, y+j))
    return places

# %%
def win(board, x, y):
    return board[x][y] == 3

# %% [markdown]
# Minimax

# %%
def minimax(board, players, playerAct, depth, alpha, beta, maximizingPlayer):
    if win(board, *players[(playerAct-1) % 4]):
        return -1 if maximizingPlayer else 1
    if depth == 0:
        return 0
    for move in movesPlayer(board, players, *players[playerAct]):
        newPlayers = players[:]
        newPlayers[playerAct] = move
        for construct in constructsPlayer(board, newPlayers, *newPlayers[playerAct]):
            newBoard = [row[:] for row in board]
            newBoard[construct[0]][construct[1]] += 1
            value = minimax(newBoard, newPlayers, (playerAct+1) %
                            4, depth-1, alpha, beta, not maximizingPlayer)
            if maximizingPlayer:
                alpha = max(alpha, value)
                if alpha >= beta:
                    return alpha
            else:
                beta = min(beta, value)
                if beta <= alpha:
                    return beta
    return alpha if maximizingPlayer else beta

# %%
def meanimean(board, players, playerAct, depth, maximizingPlayer):
    if win(board, *players[(playerAct-1) % 4]):
        return -1 if maximizingPlayer else 1
    if depth <= 0:
        return 0
    sum = 0
    nbActions = 0
    for move in movesPlayer(board, players, *players[playerAct]):
        newPlayers = players[:]
        newPlayers[playerAct] = move
        for construct in constructsPlayer(board, newPlayers, *newPlayers[playerAct]):
            newBoard = [row[:] for row in board]
            newBoard[construct[0]][construct[1]] += 1
            value = meanimean(newBoard, newPlayers, (playerAct+1) %
                            4, depth-1, not maximizingPlayer)
            sum += value
            nbActions += 1
    if nbActions == 0: #pion bloqué
        return 0.5 if maximizingPlayer else -0.5
    return sum / nbActions

# %%
def getBestMove(board, players, playerAct, depth):
    bestValue = -2
    bestMove = None
    bestConstruct = None
    bestMean = -2
    while bestMove == None:
        for move in movesPlayer(board, players, *players[playerAct]):
            newPlayers = players[:]
            newPlayers[playerAct] = move
            for construct in constructsPlayer(board, newPlayers, *newPlayers[playerAct]):
                if depth == 0:
                    return move, construct
                newBoard = [row[:] for row in board]
                newBoard[construct[0]][construct[1]] += 1
                value = minimax(newBoard, newPlayers, (playerAct+1) %
                                4, depth-1, bestValue, 1, False)
                if value != None and value > bestValue:
                    bestValue = value
                    bestMove = move
                    bestConstruct = construct
                    bestMean = meanimean(newBoard, newPlayers, (playerAct+1) % 4, depth-3, False)
                    if bestValue >= 1:
                        return bestMove, bestConstruct
                elif value == bestValue:
                    newMean = meanimean(newBoard, newPlayers, (playerAct+1) % 4, depth-3, False)
                    if newMean > bestMean:
                        bestMean = newMean
                        bestMove = move
                        bestConstruct = construct
        depth -= 1
    return bestMove, bestConstruct

# %%
import threading
import time

class threadWithReturn(threading.Thread):
    def __init__(self, *args, **kwargs):
        super(threadWithReturn, self).__init__(*args, **kwargs)
        self._return = None
    def run(self):
        if self._target is not None:
            self._return = self._target(*self._args, **self._kwargs)

def playProgressive(board, players, playerAct, depth):
    time_start = time.time()
    act_depth = 0
    while act_depth <= depth:
        thread = threadWithReturn(target=getBestMove, args=(board, players, playerAct, act_depth))
        thread.start()
        while time.time() - time_start <= 5 and thread.is_alive():
            time.sleep(0.1)
        if time.time() - time_start > 5:
            print(act_depth - 1)
            return move, construct
        act_depth += 1
        move, construct = thread._return
    print(depth)
    return move, construct

# %%
class TktBot3(Player):
    """
    Minimax + Monte Carlo Tree Search bot
    """

    def name(self):
        return "Tkt bot 3"

    # Placement of the pawns
    def place_pawn(self, board, pawn):
        my_choice = (2, 2) if (2, 2) in board.get_possible_movement_positions(
            pawn) else random.choice(board.get_possible_movement_positions(pawn))
        return my_choice

    # Movement and building
    def play_move(self, board, pawn):
        return playProgressive(
                board.board, [player.pos for player in board.pawns], pawn.number - 1, 20)

# %% [markdown]
# Test

# %%
from santorinai.tester import Tester
from santorinai.player_examples.random_player import RandomPlayer
from santorinai.player_examples.first_choice_player import FirstChoicePlayer
from santorinai.player_examples.basic_player import BasicPlayer
from TktBot2 import TktBot2

tester = Tester()
tester.delay_between_moves = 0
tester.display_board = False
tester.verbose_level = 2

p1 = TktBot3()
p2 = TktBot2()

tester.play_1v1(p1, p2, nb_games = 70)
# Out:
# Game 1
# Player Tkt bot 2 is placing pawn 1
#    Pawn placed at position (2, 2)
# Player Tkt bot 3 is placing pawn 2
#    Pawn placed at position (3, 1)
# Player Tkt bot 2 is placing pawn 3
#    Pawn placed at position (4, 3)
# Player Tkt bot 3 is placing pawn 4
#    Pawn placed at position (1, 0)
#
# Playing the game
#    Current pawn: pawn 1 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 30
# _0 _0 _0 _0 _0
# _0 10 _0 20 _0
# _1 40 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (3, 1)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (2, 0) and built at position (2, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 30
# _0 _0 _0 _0 _0
# _0 10 _1 _0 _0
# _1 40 20 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (4, 3)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (3, 2) and built at position (2, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 _0 _0 30 _0
# _0 10 _2 _0 _0
# _1 40 20 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 0)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (0, 0) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 _0 _0 30 _0
# _1 10 _2 _0 _0
# 41 _0 20 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 1) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _1 _0 _0 30 _0
# 11 _0 _2 _0 _0
# 41 _0 20 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (2, 0)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (1, 0) and built at position (1, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _1 _0 _0 30 _0
# 11 _1 _2 _0 _0
# 41 20 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (3, 2)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (2, 2) and built at position (1, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _1 _0 30 _0 _0
# 11 _2 _2 _0 _0
# 41 20 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 0)
# Player Tkt bot 2 is moving pawn 4
# 7
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _1 _0 30 _0 _0
# 11 42 _2 _0 _0
# _2 20 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 1)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (1, 2) and built at position (0, 3)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# _1 10 30 _0 _0
# _1 42 _2 _0 _0
# _2 20 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 0)
# Player Tkt bot 2 is moving pawn 2
# 20
#    Pawn moved at position (0, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# _1 10 30 _0 _0
# 21 42 _2 _0 _0
# _3 _0 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (2, 3) and built at position (1, 3)
#
# _0 _0 _0 _0 _0
# _1 _1 30 _0 _0
# _1 10 _0 _0 _0
# 21 42 _2 _0 _0
# _3 _0 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 4
# 20
#    Pawn moved at position (0, 0) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _1 _1 30 _0 _0
# _1 10 _0 _0 _0
# 21 _2 _2 _0 _0
# 43 _0 _0 _0 _0
#
# Player Tkt bot 2 wins!
# Game 2
# Player Tkt bot 2 is placing pawn 1
#    Pawn placed at position (2, 2)
# Player Tkt bot 3 is placing pawn 2
#    Pawn placed at position (0, 0)
# Player Tkt bot 2 is placing pawn 3
#    Pawn placed at position (2, 3)
# Player Tkt bot 3 is placing pawn 4
#    Pawn placed at position (1, 4)
#
# Playing the game
#    Current pawn: pawn 1 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 1) and built at position (0, 1)
#
# _0 40 _0 _0 _0
# _0 _0 30 _0 _0
# _0 _0 _0 _0 _0
# _1 10 _0 _0 _0
# 20 _0 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 0)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (0, 1) and built at position (0, 0)
#
# _0 40 _0 _0 _0
# _0 _0 30 _0 _0
# _0 _0 _0 _0 _0
# 21 10 _0 _0 _0
# _1 _0 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (2, 3)
# Player Tkt bot 3 is moving pawn 3
# 4
#    Pawn moved at position (1, 2) and built at position (0, 2)
#
# _0 40 _0 _0 _0
# _0 _0 _0 _0 _0
# _1 30 _0 _0 _0
# 21 10 _0 _0 _0
# _1 _0 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 4)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 40 _0 _0 _0 _0
# _2 30 _0 _0 _0
# 21 10 _0 _0 _0
# _1 _0 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 0) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# 40 _0 _0 _0 _0
# _2 30 _0 _0 _0
# 21 _0 _0 _0 _0
# 11 _1 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 1)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (0, 2) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# 40 _0 _0 _0 _0
# 22 30 _0 _0 _0
# _2 _0 _0 _0 _0
# 11 _1 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 2)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (1, 1) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# 40 _0 _0 _0 _0
# 22 _0 _0 _0 _0
# _3 30 _0 _0 _0
# 11 _1 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 3)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 40 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 22 _0 _0 _0 _0
# _3 30 _0 _0 _0
# 11 _1 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 0)
# Player Tkt bot 3 is moving pawn 1
# 7
#    Pawn moved at position (1, 0) and built at position (0, 1)
#
# 40 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 22 _0 _0 _0 _0
# _4 30 _0 _0 _0
# _1 11 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 2)
# Player Tkt bot 2 is moving pawn 2
# 7
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# 40 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# _3 _0 _0 _0 _0
# _4 30 _0 _0 _0
# _1 11 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (0, 0) and built at position (1, 1)
#
# 40 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# _3 _0 _0 _0 _0
# _4 _1 _0 _0 _0
# 31 11 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 4)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (1, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 21 40 _0 _0 _0
# _4 _0 _0 _0 _0
# _4 _1 _0 _0 _0
# 31 11 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 0)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (1, 1) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# 21 40 _0 _0 _0
# _4 _0 _0 _0 _0
# _4 11 _0 _0 _0
# 31 _2 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 3)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 20 _0 _0 _0 _0
# _2 40 _0 _0 _0
# _4 _0 _0 _0 _0
# _4 11 _0 _0 _0
# 31 _2 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 0)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (1, 0) and built at position (0, 0)
#
# 20 _0 _0 _0 _0
# _2 40 _0 _0 _0
# _4 _0 _0 _0 _0
# _4 11 _0 _0 _0
# _2 32 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 3)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (1, 2) and built at position (0, 3)
#
# 20 _0 _0 _0 _0
# _3 _0 _0 _0 _0
# _4 40 _0 _0 _0
# _4 11 _0 _0 _0
# _2 32 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 7
#    Pawn moved at position (0, 0) and built at position (1, 1)
#
# 20 _0 _0 _0 _0
# _3 _0 _0 _0 _0
# _4 40 _0 _0 _0
# _4 _2 _0 _0 _0
# 12 32 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 4)
# Player Tkt bot 2 is moving pawn 2
# 8
#    Pawn moved at position (1, 3) and built at position (0, 3)
#
# _0 _0 _0 _0 _0
# _4 20 _0 _0 _0
# _4 40 _0 _0 _0
# _4 _2 _0 _0 _0
# 12 32 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 0)
# Player Tkt bot 3 is moving pawn 3
# 7
#    Pawn moved at position (1, 1) and built at position (2, 0)
#
# _0 _0 _0 _0 _0
# _4 20 _0 _0 _0
# _4 40 _0 _0 _0
# _4 32 _0 _0 _0
# 12 _2 _1 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 2)
# Player Tkt bot 2 is moving pawn 4
# 20
#    Pawn moved at position (2, 1) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _4 20 _0 _0 _0
# _4 _0 _0 _0 _0
# _4 32 40 _0 _0
# 12 _3 _1 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 0)
# Player Tkt bot 3 is moving pawn 1
# 20
#    Pawn moved at position (1, 0) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _4 20 _0 _0 _0
# _4 _0 _0 _0 _0
# _4 32 40 _0 _0
# _2 13 _1 _0 _0
#
# Player Tkt bot 3 wins!
# Game 3
# Player Tkt bot 2 is placing pawn 1
#    Pawn placed at position (2, 2)
# Player Tkt bot 3 is placing pawn 2
#    Pawn placed at position (3, 2)
# Player Tkt bot 2 is placing pawn 3
#    Pawn placed at position (0, 3)
# Player Tkt bot 3 is placing pawn 4
#    Pawn placed at position (4, 0)
#
# Playing the game
#    Current pawn: pawn 1 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# _0 _0 _0 20 _0
# _0 10 _0 _0 _0
# _1 _0 _0 _0 40
#
#    Current pawn: pawn 2 of player 2 at position (3, 2)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (2, 1) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 10 20 _0 _0
# _1 _1 _0 _0 40
#
#    Current pawn: pawn 3 of player 1 at position (0, 3)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 2) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# _1 10 20 _0 _0
# _1 _1 _0 _0 40
#
#    Current pawn: pawn 4 of player 2 at position (4, 0)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (3, 0) and built at position (2, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# _1 10 20 _0 _0
# _1 _1 _1 40 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 0) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# _2 _0 20 _0 _0
# 11 _1 _1 40 _0
#
#    Current pawn: pawn 2 of player 2 at position (2, 1)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (1, 0) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# _3 _0 _0 _0 _0
# 11 21 _1 40 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 2)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (1, 1) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _4 30 _0 _0 _0
# 11 21 _1 40 _0
#
#    Current pawn: pawn 4 of player 2 at position (3, 0)
# Player Tkt bot 2 is moving pawn 4
# 20
#    Pawn moved at position (2, 0) and built at position (2, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _4 30 _1 _0 _0
# 11 21 41 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 0)
#    The pawn cannot move
#    Current pawn: pawn 2 of player 2 at position (1, 0)
# Player Tkt bot 2 is moving pawn 2
# 7
#    Pawn moved at position (2, 1) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _4 30 21 _0 _0
# 11 _2 41 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (2, 2) and built at position (1, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 _0 30 _0 _0
# _4 _1 21 _0 _0
# 11 _2 41 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (2, 0)
# Player Tkt bot 2 is moving pawn 4
# 7
#    Pawn moved at position (1, 1) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 _0 30 _0 _0
# _4 41 21 _0 _0
# 11 _3 _1 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 0)
#    The pawn cannot move
#    Current pawn: pawn 2 of player 2 at position (2, 1)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (1, 2) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _1 20 30 _0 _0
# _4 41 _1 _0 _0
# 11 _3 _1 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (1, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# _0 30 _0 _0 _0
# _2 20 _0 _0 _0
# _4 41 _1 _0 _0
# 11 _3 _1 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (0, 2) and built at position (0, 3)
#
# _0 _0 _0 _0 _0
# _1 30 _0 _0 _0
# 42 20 _0 _0 _0
# _4 _1 _1 _0 _0
# 11 _3 _1 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 0)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _1 30 _0 _0 _0
# 42 20 _0 _0 _0
# _4 11 _1 _0 _0
# _2 _3 _1 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 2)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (0, 3) and built at position (0, 4)
#
# _1 _0 _0 _0 _0
# 21 30 _0 _0 _0
# 42 _0 _0 _0 _0
# _4 11 _1 _0 _0
# _2 _3 _1 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 3)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 4) and built at position (1, 3)
#
# 31 _0 _0 _0 _0
# 21 _1 _0 _0 _0
# 42 _0 _0 _0 _0
# _4 11 _1 _0 _0
# _2 _3 _1 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 2)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (1, 2) and built at position (0, 2)
#
# 31 _0 _0 _0 _0
# 21 _1 _0 _0 _0
# _3 40 _0 _0 _0
# _4 11 _1 _0 _0
# _2 _3 _1 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (0, 0) and built at position (1, 1)
#
# 31 _0 _0 _0 _0
# 21 _1 _0 _0 _0
# _3 40 _0 _0 _0
# _4 _2 _1 _0 _0
# 12 _3 _1 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 3)
# Player Tkt bot 2 is moving pawn 2
# 8
#    Pawn moved at position (1, 3) and built at position (0, 2)
#
# 31 _0 _0 _0 _0
# _1 21 _0 _0 _0
# _4 40 _0 _0 _0
# _4 _2 _1 _0 _0
# 12 _3 _1 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 4)
# Player Tkt bot 3 is moving pawn 3
# 7
#    Pawn moved at position (0, 3) and built at position (0, 4)
#
# _2 _0 _0 _0 _0
# 31 21 _0 _0 _0
# _4 40 _0 _0 _0
# _4 _2 _1 _0 _0
# 12 _3 _1 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 2)
# Player Tkt bot 2 is moving pawn 4
# 8
#    Pawn moved at position (2, 1) and built at position (1, 0)
#
# _2 _0 _0 _0 _0
# 31 21 _0 _0 _0
# _4 _0 _0 _0 _0
# _4 _2 41 _0 _0
# 12 _4 _1 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 0)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _2 _0 _0 _0 _0
# 31 21 _0 _0 _0
# _4 _0 _0 _0 _0
# _4 12 41 _0 _0
# _3 _4 _1 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 3)
# Player Tkt bot 2 is moving pawn 2
# 7
#    Pawn moved at position (0, 4) and built at position (1, 3)
#
# 22 _0 _0 _0 _0
# 31 _2 _0 _0 _0
# _4 _0 _0 _0 _0
# _4 12 41 _0 _0
# _3 _4 _1 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 3)
# Player Tkt bot 3 is moving pawn 3
# 7
#    Pawn moved at position (1, 2) and built at position (0, 3)
#
# 22 _0 _0 _0 _0
# _2 _2 _0 _0 _0
# _4 30 _0 _0 _0
# _4 12 41 _0 _0
# _3 _4 _1 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (2, 1)
# Player Tkt bot 2 is moving pawn 4
# 13
#    Pawn moved at position (2, 0) and built at position (2, 1)
#
# 22 _0 _0 _0 _0
# _2 _2 _0 _0 _0
# _4 30 _0 _0 _0
# _4 12 _2 _0 _0
# _3 _4 41 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 20
#    Pawn moved at position (0, 0) and built at position (1, 1)
#
# 22 _0 _0 _0 _0
# _2 _2 _0 _0 _0
# _4 30 _0 _0 _0
# _4 _2 _2 _0 _0
# 13 _4 41 _0 _0
#
# Player Tkt bot 3 wins!
# Game 4
# Player Tkt bot 2 is placing pawn 1
#    Pawn placed at position (2, 2)
# Player Tkt bot 3 is placing pawn 2
#    Pawn placed at position (3, 2)
# Player Tkt bot 2 is placing pawn 3
#    Pawn placed at position (1, 0)
# Player Tkt bot 3 is placing pawn 4
#    Pawn placed at position (1, 2)
#
# Playing the game
#    Current pawn: pawn 1 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 40 _0 20 _0
# _0 10 _0 _0 _0
# _1 30 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (3, 2)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (2, 1) and built at position (2, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 40 _0 _0 _0
# _0 10 20 _0 _0
# _1 30 _1 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 0)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 0) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 40 _0 _0 _0
# _1 10 20 _0 _0
# 31 _0 _1 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 2)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (0, 1) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 41 10 20 _0 _0
# 31 _0 _1 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 0) and built at position (2, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 41 _0 20 _0 _0
# 31 10 _2 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (2, 1)
# Player Tkt bot 2 is moving pawn 2
# 20
#    Pawn moved at position (1, 1) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 41 20 _0 _0 _0
# 31 10 _2 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 0)
#    The pawn cannot move
#    Current pawn: pawn 4 of player 2 at position (0, 1)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (0, 2) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 42 _0 _0 _0 _0
# _2 20 _0 _0 _0
# 31 10 _2 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 0)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (2, 1) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 42 _0 _0 _0 _0
# _2 20 10 _0 _0
# 31 _1 _2 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 2
# 7
#    Pawn moved at position (1, 0) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 42 _0 _0 _0 _0
# _3 _0 10 _0 _0
# 31 21 _2 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 0)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (1, 1) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 42 _0 _0 _0 _0
# _4 30 10 _0 _0
# _1 21 _2 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 2)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 40 _0 _0 _0 _0
# _3 _0 _0 _0 _0
# _4 30 10 _0 _0
# _1 21 _2 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (2, 1)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (1, 2) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 40 _0 _0 _0 _0
# _4 10 _0 _0 _0
# _4 30 _0 _0 _0
# _1 21 _2 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 0)
# Player Tkt bot 2 is moving pawn 2
# 7
#    Pawn moved at position (2, 0) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# 40 _0 _0 _0 _0
# _4 10 _0 _0 _0
# _4 30 _0 _0 _0
# _1 _2 22 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (2, 1) and built at position (1, 1)
#
# _0 _0 _0 _0 _0
# 40 _0 _0 _0 _0
# _4 10 _0 _0 _0
# _4 _1 30 _0 _0
# _1 _2 22 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 3)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 40 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# _4 10 _0 _0 _0
# _4 _1 30 _0 _0
# _1 _2 22 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 3) and built at position (1, 2)
#
# 40 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# _4 _1 _0 _0 _0
# _4 _1 30 _0 _0
# _1 _2 22 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (2, 0)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (1, 0) and built at position (0, 0)
#
# 40 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# _4 _1 _0 _0 _0
# _4 _1 30 _0 _0
# _2 22 _2 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (2, 1)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (1, 1) and built at position (1, 2)
#
# 40 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# _4 _2 _0 _0 _0
# _4 31 _0 _0 _0
# _2 22 _2 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 4)
# Player Tkt bot 2 is moving pawn 4
# 7
#    Pawn moved at position (1, 3) and built at position (0, 4)
#
# _1 _0 _0 _0 _0
# 11 40 _0 _0 _0
# _4 _2 _0 _0 _0
# _4 31 _0 _0 _0
# _2 22 _2 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 3)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 11 _0 _0 _0 _0
# _2 40 _0 _0 _0
# _4 _2 _0 _0 _0
# _4 31 _0 _0 _0
# _2 22 _2 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 0)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (0, 0) and built at position (1, 0)
#
# 11 _0 _0 _0 _0
# _2 40 _0 _0 _0
# _4 _2 _0 _0 _0
# _4 31 _0 _0 _0
# 22 _3 _2 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (2, 0) and built at position (1, 0)
#
# 11 _0 _0 _0 _0
# _2 40 _0 _0 _0
# _4 _2 _0 _0 _0
# _4 _1 _0 _0 _0
# 22 _4 32 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 3)
# Player Tkt bot 2 is moving pawn 4
# 7
#    Pawn moved at position (2, 2) and built at position (1, 1)
#
# 11 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _4 _2 40 _0 _0
# _4 _2 _0 _0 _0
# 22 _4 32 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 4)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (0, 3) and built at position (0, 4)
#
# _2 _0 _0 _0 _0
# 12 _0 _0 _0 _0
# _4 _2 40 _0 _0
# _4 _2 _0 _0 _0
# 22 _4 32 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 0)
# Player Tkt bot 2 is moving pawn 2
# 20
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _2 _0 _0 _0 _0
# 12 _0 _0 _0 _0
# _4 _2 40 _0 _0
# _4 22 _0 _0 _0
# _3 _4 32 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (2, 0)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (2, 1) and built at position (1, 2)
#
# _2 _0 _0 _0 _0
# 12 _0 _0 _0 _0
# _4 _3 40 _0 _0
# _4 22 30 _0 _0
# _3 _4 _2 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (2, 2)
# Player Tkt bot 2 is moving pawn 4
# 20
#    Pawn moved at position (1, 3) and built at position (1, 2)
#
# _2 _0 _0 _0 _0
# 12 40 _0 _0 _0
# _4 _4 _0 _0 _0
# _4 22 30 _0 _0
# _3 _4 _2 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 3)
# Player Tkt bot 3 is moving pawn 1
# 7
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 12 _0 _0 _0 _0
# _3 40 _0 _0 _0
# _4 _4 _0 _0 _0
# _4 22 30 _0 _0
# _3 _4 _2 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 2
# 20
#    Pawn moved at position (0, 0) and built at position (1, 1)
#
# 12 _0 _0 _0 _0
# _3 40 _0 _0 _0
# _4 _4 _0 _0 _0
# _4 _2 30 _0 _0
# 23 _4 _2 _0 _0
#
# Player Tkt bot 2 wins!
# Game 5
# Player Tkt bot 2 is placing pawn 1
#    Pawn placed at position (2, 2)
# Player Tkt bot 3 is placing pawn 2
#    Pawn placed at position (4, 2)
# Player Tkt bot 2 is placing pawn 3
#    Pawn placed at position (1, 4)
# Player Tkt bot 3 is placing pawn 4
#    Pawn placed at position (1, 2)
#
# Playing the game
#    Current pawn: pawn 1 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 30 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 40 _0 _0 20
# _0 10 _0 _0 _0
# _1 _0 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (4, 2)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (3, 1) and built at position (2, 0)
#
# _0 30 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 40 _0 _0 _0
# _0 10 _0 20 _0
# _1 _0 _1 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 4)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# _1 40 _0 _0 _0
# _0 10 _0 20 _0
# _1 _0 _1 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 2)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (0, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 40 10 _0 20 _0
# _2 _0 _1 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 2) and built at position (1, 1)
#
# _0 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# 40 _1 _0 20 _0
# _2 _0 _1 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (3, 1)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (2, 0) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# 40 _1 _0 _0 _0
# _2 _1 21 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 3)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 30 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# 40 _1 _0 _0 _0
# _2 _1 21 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 1)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (1, 0) and built at position (0, 0)
#
# 30 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# _0 _1 _0 _0 _0
# _3 41 21 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 1) and built at position (0, 0)
#
# 30 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 10 _1 _0 _0 _0
# _4 41 21 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (2, 0)
# Player Tkt bot 2 is moving pawn 2
# 7
#    Pawn moved at position (1, 1) and built at position (2, 0)
#
# 30 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 10 21 _0 _0 _0
# _4 41 _2 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 4)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 31 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 10 21 _0 _0 _0
# _4 41 _2 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 0)
# Player Tkt bot 2 is moving pawn 4
# 8
#    Pawn moved at position (2, 0) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# 31 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 10 21 _0 _0 _0
# _4 _2 42 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 1)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (1, 2) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# 31 _0 _0 _0 _0
# _2 10 _0 _0 _0
# _1 21 _0 _0 _0
# _4 _2 42 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 2
# 7
#    Pawn moved at position (0, 1) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# 31 _0 _0 _0 _0
# _2 10 _0 _0 _0
# 21 _1 _0 _0 _0
# _4 _3 42 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 3)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 30 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _2 10 _0 _0 _0
# 21 _1 _0 _0 _0
# _4 _3 42 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (2, 0)
# Player Tkt bot 2 is moving pawn 4
# 20
#    Pawn moved at position (1, 0) and built at position (1, 1)
#
# 30 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _2 10 _0 _0 _0
# 21 _1 _0 _0 _0
# _4 43 _2 _0 _0
#
# Player Tkt bot 2 wins!
# Game 6
# Player Tkt bot 2 is placing pawn 1
#    Pawn placed at position (2, 2)
# Player Tkt bot 3 is placing pawn 2
#    Pawn placed at position (3, 3)
# Player Tkt bot 2 is placing pawn 3
#    Pawn placed at position (2, 4)
# Player Tkt bot 3 is placing pawn 4
#    Pawn placed at position (3, 0)
#
# Playing the game
#    Current pawn: pawn 1 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 30 _0 _0
# _0 _0 _0 20 _0
# _0 _0 _0 _0 _0
# _0 10 _0 _0 _0
# _1 _0 _0 40 _0
#
#    Current pawn: pawn 2 of player 2 at position (3, 3)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (2, 2) and built at position (1, 2)
#
# _0 _0 30 _0 _0
# _0 _0 _0 _0 _0
# _0 _1 20 _0 _0
# _0 10 _0 _0 _0
# _1 _0 _0 40 _0
#
#    Current pawn: pawn 3 of player 1 at position (2, 4)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (1, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# _0 30 _0 _0 _0
# _1 _1 20 _0 _0
# _0 10 _0 _0 _0
# _1 _0 _0 40 _0
#
#    Current pawn: pawn 4 of player 2 at position (3, 0)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (2, 0) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _0 30 _0 _0 _0
# _1 _1 20 _0 _0
# _0 10 _0 _0 _0
# _1 _1 40 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 0) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _0 30 _0 _0 _0
# _1 _1 20 _0 _0
# _0 _0 _0 _0 _0
# 11 _2 40 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (2, 2)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (1, 1) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 30 _0 _0 _0
# _1 _1 _0 _0 _0
# _1 20 _0 _0 _0
# 11 _2 40 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 3)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 2) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 31 _1 _0 _0 _0
# _2 20 _0 _0 _0
# 11 _2 40 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (2, 0)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (2, 1) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 31 _1 _0 _0 _0
# _2 20 40 _0 _0
# 11 _3 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 0)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (0, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 31 _1 _0 _0 _0
# 12 20 40 _0 _0
# _2 _3 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (1, 2) and built at position (0, 3)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 31 21 _0 _0 _0
# 12 _0 40 _0 _0
# _2 _3 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 2)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# _1 21 _0 _0 _0
# 12 30 40 _0 _0
# _3 _3 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (2, 1)
# Player Tkt bot 2 is moving pawn 4
# 9
#    Pawn moved at position (2, 0) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# _1 21 _0 _0 _0
# 12 30 _0 _0 _0
# _3 _4 40 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 1)
# Player Tkt bot 3 is moving pawn 1
# 20
#    Pawn moved at position (0, 0) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# _1 21 _0 _0 _0
# _2 30 _0 _0 _0
# 13 _4 40 _0 _0
#
# Player Tkt bot 3 wins!
# Game 7
# Player Tkt bot 2 is placing pawn 1
#    Pawn placed at position (2, 2)
# Player Tkt bot 3 is placing pawn 2
#    Pawn placed at position (2, 0)
# Player Tkt bot 2 is placing pawn 3
#    Pawn placed at position (3, 0)
# Player Tkt bot 3 is placing pawn 4
#    Pawn placed at position (2, 4)
#
# Playing the game
#    Current pawn: pawn 1 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 40 _0 _0
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 10 _0 _0 _0
# _1 _0 20 30 _0
#
#    Current pawn: pawn 2 of player 2 at position (2, 0)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (1, 0) and built at position (0, 0)
#
# _0 _0 40 _0 _0
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 10 _0 _0 _0
# _2 20 _0 30 _0
#
#    Current pawn: pawn 3 of player 1 at position (3, 0)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (2, 0) and built at position (2, 1)
#
# _0 _0 40 _0 _0
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 10 _1 _0 _0
# _2 20 30 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (2, 4)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (1, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# _0 40 _0 _0 _0
# _1 _0 _0 _0 _0
# _0 10 _1 _0 _0
# _2 20 30 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 40 _0 _0 _0
# _1 _0 _0 _0 _0
# 10 _0 _1 _0 _0
# _3 20 30 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 0)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 40 _0 _0 _0
# _1 _0 _0 _0 _0
# 10 20 _1 _0 _0
# _4 _0 30 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (2, 0)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (2, 1) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _0 40 _0 _0 _0
# _1 _0 _0 _0 _0
# 10 20 31 _0 _0
# _4 _1 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 3)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (0, 2) and built at position (0, 3)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 41 _0 _0 _0 _0
# 10 20 31 _0 _0
# _4 _1 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 1)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 0) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 41 _0 _0 _0 _0
# _1 20 31 _0 _0
# _4 11 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 2
# 7
#    Pawn moved at position (0, 1) and built at position (1, 1)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 41 _0 _0 _0 _0
# 21 _1 31 _0 _0
# _4 11 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (2, 1)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (2, 0) and built at position (2, 1)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 41 _0 _0 _0 _0
# 21 _1 _2 _0 _0
# _4 11 30 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 2)
# Player Tkt bot 2 is moving pawn 4
# 7
#    Pawn moved at position (1, 1) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 21 41 _2 _0 _0
# _4 11 30 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 0)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (2, 1) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 21 41 12 _0 _0
# _4 _2 30 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 1)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (0, 2) and built at position (0, 3)
#
# _0 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 22 _0 _0 _0 _0
# _1 41 12 _0 _0
# _4 _2 30 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (2, 0)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (3, 1) and built at position (2, 0)
#
# _0 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 22 _0 _0 _0 _0
# _1 41 12 30 _0
# _4 _2 _1 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (1, 0) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 22 _0 _0 _0 _0
# _2 _1 12 30 _0
# _4 42 _1 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (2, 1)
# Player Tkt bot 3 is moving pawn 1
# 4
#    Pawn moved at position (1, 1) and built at position (1, 2)
#
# _0 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 22 _1 _0 _0 _0
# _2 11 _2 30 _0
# _4 42 _1 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 2)
# Player Tkt bot 2 is moving pawn 2
# 20
#    Pawn moved at position (0, 1) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _3 _1 _0 _0 _0
# 22 11 _2 30 _0
# _4 42 _1 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (3, 1)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (4, 0) and built at position (3, 0)
#
# _0 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _3 _1 _0 _0 _0
# 22 11 _2 _0 _0
# _4 42 _1 _1 30
#
#    Current pawn: pawn 4 of player 2 at position (1, 0)
# Player Tkt bot 2 is moving pawn 4
# 20
#    Pawn moved at position (2, 0) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _3 _1 _0 _0 _0
# 22 11 _2 _0 _0
# _4 _3 41 _1 30
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 7
#    Pawn moved at position (2, 1) and built at position (1, 2)
#
# _0 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _3 _2 _0 _0 _0
# 22 _1 12 _0 _0
# _4 _3 41 _1 30
#
#    Current pawn: pawn 2 of player 2 at position (0, 1)
# Player Tkt bot 2 is moving pawn 2
# 20
#    Pawn moved at position (0, 2) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 23 _2 _0 _0 _0
# _2 _1 12 _0 _0
# _4 _3 41 _1 30
#
# Player Tkt bot 2 wins!
# Game 8
# Player Tkt bot 2 is placing pawn 1
#    Pawn placed at position (2, 2)
# Player Tkt bot 3 is placing pawn 2
#    Pawn placed at position (2, 0)
# Player Tkt bot 2 is placing pawn 3
#    Pawn placed at position (4, 3)
# Player Tkt bot 3 is placing pawn 4
#    Pawn placed at position (1, 1)
#
# Playing the game
#    Current pawn: pawn 1 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 2) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 30
# _0 10 _0 _0 _0
# _1 40 _0 _0 _0
# _0 _0 20 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (2, 0)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (1, 0) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 30
# _0 10 _0 _0 _0
# _1 40 _0 _0 _0
# _1 20 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (4, 3)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (3, 2) and built at position (2, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 10 _0 30 _0
# _1 40 _1 _0 _0
# _1 20 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (0, 0) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 10 _0 30 _0
# _2 _0 _1 _0 _0
# 41 20 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 2)
# Player Tkt bot 3 is moving pawn 1
# 4
#    Pawn moved at position (0, 2) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 10 _0 _0 30 _0
# _3 _0 _1 _0 _0
# 41 20 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 0)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (1, 1) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 10 _0 _0 30 _0
# _4 20 _1 _0 _0
# 41 _0 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (3, 2)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (2, 1) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 10 _0 _0 _0 _0
# _4 20 31 _0 _0
# 41 _1 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 0)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (1, 0) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 10 _0 _0 _0 _0
# _4 20 31 _0 _0
# _2 41 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 10 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# _4 20 31 _0 _0
# _2 41 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (0, 2) and built at position (1, 1)
#
# _0 _0 _0 _0 _0
# 10 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# _4 _1 31 _0 _0
# _2 41 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (2, 1)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# 10 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# _4 31 _1 _0 _0
# _3 41 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 0)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (2, 0) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# 10 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# _4 31 _1 _0 _0
# _3 _2 40 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 3)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 10 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# _4 31 _1 _0 _0
# _3 _2 40 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 2)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# 10 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _4 31 _1 _0 _0
# _3 _2 40 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (1, 0) and built at position (1, 1)
#
# 10 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _4 _2 _1 _0 _0
# _3 32 40 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (2, 0)
# Player Tkt bot 2 is moving pawn 4
# 9
#    Pawn moved at position (2, 1) and built at position (1, 1)
#
# 10 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _4 _3 41 _0 _0
# _3 32 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 4)
# Player Tkt bot 3 is moving pawn 1
# 7
#    Pawn moved at position (1, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 21 10 _0 _0 _0
# _3 _0 _0 _0 _0
# _4 _3 41 _0 _0
# _3 32 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 3)
# Player Tkt bot 2 is moving pawn 2
# 8
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 20 _0 _0 _0 _0
# _2 10 _0 _0 _0
# _3 _0 _0 _0 _0
# _4 _3 41 _0 _0
# _3 32 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 0)
# Player Tkt bot 3 is moving pawn 3
# 20
#    Pawn moved at position (0, 0) and built at position (1, 0)
#
# 20 _0 _0 _0 _0
# _2 10 _0 _0 _0
# _3 _0 _0 _0 _0
# _4 _3 41 _0 _0
# 33 _2 _0 _0 _0
#
# Player Tkt bot 3 wins!
# Game 9
# Player Tkt bot 2 is placing pawn 1
#    Pawn placed at position (2, 2)
# Player Tkt bot 3 is placing pawn 2
#    Pawn placed at position (1, 1)
# Player Tkt bot 2 is placing pawn 3
#    Pawn placed at position (1, 0)
# Player Tkt bot 3 is placing pawn 4
#    Pawn placed at position (1, 4)
#
# Playing the game
#    Current pawn: pawn 1 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 2) and built at position (0, 1)
#
# _0 40 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 10 _0 _0 _0
# _1 20 _0 _0 _0
# _0 30 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (0, 1) and built at position (0, 0)
#
# _0 40 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 10 _0 _0 _0
# 21 _0 _0 _0 _0
# _1 30 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 0)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 0) and built at position (1, 0)
#
# _0 40 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 10 _0 _0 _0
# 21 _0 _0 _0 _0
# 31 _1 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 4)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 40 _0 _0 _0 _0
# _1 10 _0 _0 _0
# 21 _0 _0 _0 _0
# 31 _1 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 2) and built at position (1, 1)
#
# _0 _0 _0 _0 _0
# 40 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# 21 _1 _0 _0 _0
# 31 _1 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 1)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (1, 0) and built at position (2, 0)
#
# _0 _0 _0 _0 _0
# 40 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# _1 _1 _0 _0 _0
# 31 21 _1 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 0)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# 40 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# 31 _1 _0 _0 _0
# _2 21 _1 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 3)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 40 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# 31 _1 _0 _0 _0
# _2 21 _1 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# 40 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 31 _1 _0 _0 _0
# _2 21 _1 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 0)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (0, 0) and built at position (1, 0)
#
# 40 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 31 _1 _0 _0 _0
# 22 _2 _1 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 1)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (0, 2) and built at position (1, 2)
#
# 40 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# 32 _1 _0 _0 _0
# _1 _1 _0 _0 _0
# 22 _2 _1 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 4)
# Player Tkt bot 2 is moving pawn 4
# 7
#    Pawn moved at position (1, 3) and built at position (0, 4)
#
# _1 _0 _0 _0 _0
# 11 40 _0 _0 _0
# 32 _1 _0 _0 _0
# _1 _1 _0 _0 _0
# 22 _2 _1 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 3)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 2) and built at position (1, 1)
#
# _1 _0 _0 _0 _0
# _1 40 _0 _0 _0
# 32 11 _0 _0 _0
# _1 _2 _0 _0 _0
# 22 _2 _1 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 0)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (0, 1) and built at position (0, 0)
#
# _1 _0 _0 _0 _0
# _1 40 _0 _0 _0
# 32 11 _0 _0 _0
# 21 _2 _0 _0 _0
# _3 _2 _1 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 2)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _1 _0 _0 _0 _0
# _1 40 _0 _0 _0
# _2 11 _0 _0 _0
# 21 32 _0 _0 _0
# _4 _2 _1 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 3)
# Player Tkt bot 2 is moving pawn 4
# 4
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# _1 _0 _0 _0 _0
# 41 _0 _0 _0 _0
# _3 11 _0 _0 _0
# 21 32 _0 _0 _0
# _4 _2 _1 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 2)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (2, 1) and built at position (1, 0)
#
# _1 _0 _0 _0 _0
# 41 _0 _0 _0 _0
# _3 _1 _0 _0 _0
# 21 32 10 _0 _0
# _4 _3 _1 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 1)
# Player Tkt bot 2 is moving pawn 2
# 7
#    Pawn moved at position (1, 2) and built at position (0, 1)
#
# _1 _0 _0 _0 _0
# 41 _0 _0 _0 _0
# _3 21 _0 _0 _0
# _2 32 10 _0 _0
# _4 _3 _1 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (0, 1) and built at position (0, 2)
#
# _1 _0 _0 _0 _0
# 41 _0 _0 _0 _0
# _4 21 _0 _0 _0
# 32 _2 10 _0 _0
# _4 _3 _1 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 3)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 41 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _4 21 _0 _0 _0
# 32 _2 10 _0 _0
# _4 _3 _1 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (2, 1)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (2, 0) and built at position (1, 1)
#
# 41 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _4 21 _0 _0 _0
# 32 _3 _0 _0 _0
# _4 _3 11 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 2)
# Player Tkt bot 2 is moving pawn 2
# 7
#    Pawn moved at position (0, 3) and built at position (1, 2)
#
# 41 _0 _0 _0 _0
# 22 _0 _0 _0 _0
# _4 _2 _0 _0 _0
# 32 _3 _0 _0 _0
# _4 _3 11 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 1)
# Player Tkt bot 3 is moving pawn 3
# 20
#    Pawn moved at position (1, 0) and built at position (0, 1)
#
# 41 _0 _0 _0 _0
# 22 _0 _0 _0 _0
# _4 _2 _0 _0 _0
# _2 _3 _0 _0 _0
# _4 33 11 _0 _0
#
# Player Tkt bot 3 wins!
# Game 10
# Player Tkt bot 2 is placing pawn 1
#    Pawn placed at position (2, 2)
# Player Tkt bot 3 is placing pawn 2
#    Pawn placed at position (1, 3)
# Player Tkt bot 2 is placing pawn 3
#    Pawn placed at position (0, 1)
# Player Tkt bot 3 is placing pawn 4
#    Pawn placed at position (3, 0)
#
# Playing the game
#    Current pawn: pawn 1 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 20 _0 _0 _0
# _0 _0 _0 _0 _0
# 30 10 _0 _0 _0
# _1 _0 _0 40 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 3)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (0, 2) and built at position (0, 3)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 20 _0 _0 _0 _0
# 30 10 _0 _0 _0
# _1 _0 _0 40 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 1)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 0) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 20 _0 _0 _0 _0
# _1 10 _0 _0 _0
# 31 _0 _0 40 _0
#
#    Current pawn: pawn 4 of player 2 at position (3, 0)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (2, 0) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 20 _0 _0 _0 _0
# _1 10 _0 _0 _0
# 31 _1 40 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 0) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 20 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 31 11 40 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 2)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (1, 1) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _3 20 _0 _0 _0
# 31 11 40 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 0)
#    The pawn cannot move
#    Current pawn: pawn 4 of player 2 at position (2, 0)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (2, 1) and built at position (1, 2)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# _0 _1 _0 _0 _0
# _3 20 40 _0 _0
# 31 11 _0 _0 _0
#
# ...
# 22 _0 _0 _0 _0
# _4 10 _0 _0 _0
# _4 _3 _0 _0 _0
# 42 31 _2 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 3)
# Player Tkt bot 2 is moving pawn 2
# 20
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 23 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _4 10 _0 _0 _0
# _4 _3 _0 _0 _0
# 42 31 _2 _0 _0
#
# Player Tkt bot 2 wins!
# Game 68
# Player Tkt bot 2 is placing pawn 1
#    Pawn placed at position (2, 2)
# Player Tkt bot 3 is placing pawn 2
#    Pawn placed at position (0, 2)
# Player Tkt bot 2 is placing pawn 3
#    Pawn placed at position (2, 1)
# Player Tkt bot 3 is placing pawn 4
#    Pawn placed at position (4, 3)
#
# Playing the game
#    Current pawn: pawn 1 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 1
# 4
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 40
# 20 _0 _0 _0 _0
# _0 10 30 _0 _0
# _1 _0 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 2)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (0, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 40
# _0 _0 _0 _0 _0
# 20 10 30 _0 _0
# _2 _0 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (2, 1)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (1, 0) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 40
# _0 _0 _0 _0 _0
# 20 10 _0 _0 _0
# _3 30 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (4, 3)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (3, 2) and built at position (2, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 _0 _0 40 _0
# 20 10 _1 _0 _0
# _3 30 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 2) and built at position (0, 3)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 10 _0 _0 40 _0
# 20 _0 _1 _0 _0
# _3 30 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 1)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 10 _0 _0 40 _0
# _0 20 _1 _0 _0
# _4 30 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 0)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 1) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 10 _0 _0 40 _0
# 30 20 _1 _0 _0
# _4 _1 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (3, 2)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (2, 1) and built at position (1, 0)
#
# _0 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 10 _0 _0 _0 _0
# 30 20 41 _0 _0
# _4 _2 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 2)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 30 20 41 _0 _0
# _4 _2 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (0, 2) and built at position (1, 1)
#
# _0 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# 30 _1 41 _0 _0
# _4 _2 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 1)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (1, 1) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# _1 31 41 _0 _0
# _4 _2 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (2, 1)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (1, 0) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# 11 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# _2 31 _1 _0 _0
# _4 42 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 3)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 10 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# _2 31 _1 _0 _0
# _4 42 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 2)
# Player Tkt bot 2 is moving pawn 2
# 7
#    Pawn moved at position (0, 1) and built at position (0, 2)
#
# 10 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# _2 _0 _0 _0 _0
# 22 31 _1 _0 _0
# _4 42 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 2) and built at position (0, 3)
#
# 10 _0 _0 _0 _0
# _3 _0 _0 _0 _0
# 32 _0 _0 _0 _0
# 22 _1 _1 _0 _0
# _4 42 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 0)
# Player Tkt bot 2 is moving pawn 4
# 20
#    Pawn moved at position (1, 1) and built at position (1, 0)
#
# 10 _0 _0 _0 _0
# _3 _0 _0 _0 _0
# 32 _0 _0 _0 _0
# 22 41 _1 _0 _0
# _4 _3 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 4)
# Player Tkt bot 3 is moving pawn 1
# 7
#    Pawn moved at position (1, 3) and built at position (0, 4)
#
# _1 _0 _0 _0 _0
# _3 10 _0 _0 _0
# 32 _0 _0 _0 _0
# 22 41 _1 _0 _0
# _4 _3 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 1)
# Player Tkt bot 2 is moving pawn 2
# 20
#    Pawn moved at position (1, 0) and built at position (0, 1)
#
# _1 _0 _0 _0 _0
# _3 10 _0 _0 _0
# 32 _0 _0 _0 _0
# _2 41 _1 _0 _0
# _4 23 _0 _0 _0
#
# Player Tkt bot 2 wins!
# Game 69
# Player Tkt bot 2 is placing pawn 1
#    Pawn placed at position (2, 2)
# Player Tkt bot 3 is placing pawn 2
#    Pawn placed at position (4, 4)
# Player Tkt bot 2 is placing pawn 3
#    Pawn placed at position (3, 4)
# Player Tkt bot 3 is placing pawn 4
#    Pawn placed at position (0, 4)
#
# Playing the game
#    Current pawn: pawn 1 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# 40 _0 _0 30 20
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# _0 10 _0 _0 _0
# _1 _0 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (4, 4)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (3, 3) and built at position (2, 2)
#
# 40 _0 _0 30 _0
# _0 _0 _0 20 _0
# _0 _0 _1 _0 _0
# _0 10 _0 _0 _0
# _1 _0 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (3, 4)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (2, 3) and built at position (1, 2)
#
# 40 _0 _0 _0 _0
# _0 _0 30 20 _0
# _0 _1 _1 _0 _0
# _0 10 _0 _0 _0
# _1 _0 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 4)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 40 _0 30 20 _0
# _1 _1 _1 _0 _0
# _0 10 _0 _0 _0
# _1 _0 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (0, 0) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# 40 _0 30 20 _0
# _1 _1 _1 _0 _0
# _1 _0 _0 _0 _0
# 11 _0 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (3, 3)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (2, 2) and built at position (1, 1)
#
# _0 _0 _0 _0 _0
# 40 _0 30 _0 _0
# _1 _1 21 _0 _0
# _1 _1 _0 _0 _0
# 11 _0 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (2, 3)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (1, 2) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# 40 _0 _0 _0 _0
# _1 31 21 _0 _0
# _2 _1 _0 _0 _0
# 11 _0 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 3)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (0, 2) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 41 31 21 _0 _0
# _3 _1 _0 _0 _0
# 11 _0 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 0)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 0) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 41 31 21 _0 _0
# _3 _1 _0 _0 _0
# _2 10 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (2, 2)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (1, 1) and built at position (0, 0)
#
# _0 _0 _0 _0 _0
# _0 _0 _0 _0 _0
# 41 31 _1 _0 _0
# _3 21 _0 _0 _0
# _3 10 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 2)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 3) and built at position (0, 4)
#
# _1 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# 41 _1 _1 _0 _0
# _3 21 _0 _0 _0
# _3 10 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 2)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (1, 2) and built at position (0, 1)
#
# _1 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# _1 41 _1 _0 _0
# _4 21 _0 _0 _0
# _3 10 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 0)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (2, 0) and built at position (1, 0)
#
# _1 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# _1 41 _1 _0 _0
# _4 21 _0 _0 _0
# _3 _1 10 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 2
# 7
#    Pawn moved at position (0, 2) and built at position (1, 1)
#
# _1 _0 _0 _0 _0
# 30 _0 _0 _0 _0
# 21 41 _1 _0 _0
# _4 _2 _0 _0 _0
# _3 _1 10 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 3)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 31 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 21 41 _1 _0 _0
# _4 _2 _0 _0 _0
# _3 _1 10 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 2)
# Player Tkt bot 2 is moving pawn 4
# 7
#    Pawn moved at position (1, 1) and built at position (1, 0)
#
# 31 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 21 _1 _1 _0 _0
# _4 42 _0 _0 _0
# _3 _2 10 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (2, 0)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (3, 0) and built at position (2, 0)
#
# 31 _0 _0 _0 _0
# _1 _0 _0 _0 _0
# 21 _1 _1 _0 _0
# _4 42 _0 _0 _0
# _3 _2 _1 10 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 2)
# Player Tkt bot 2 is moving pawn 2
# 20
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# 31 _0 _0 _0 _0
# 21 _0 _0 _0 _0
# _2 _1 _1 _0 _0
# _4 42 _0 _0 _0
# _3 _2 _1 10 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 4)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (1, 4) and built at position (0, 4)
#
# _2 30 _0 _0 _0
# 21 _0 _0 _0 _0
# _2 _1 _1 _0 _0
# _4 42 _0 _0 _0
# _3 _2 _1 10 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 1)
# Player Tkt bot 2 is moving pawn 4
# 20
#    Pawn moved at position (0, 0) and built at position (1, 0)
#
# _2 30 _0 _0 _0
# 21 _0 _0 _0 _0
# _2 _1 _1 _0 _0
# _4 _2 _0 _0 _0
# 43 _2 _1 10 _0
#
# Player Tkt bot 2 wins!
# Game 70
# Player Tkt bot 2 is placing pawn 1
#    Pawn placed at position (2, 2)
# Player Tkt bot 3 is placing pawn 2
#    Pawn placed at position (2, 4)
# Player Tkt bot 2 is placing pawn 3
#    Pawn placed at position (1, 1)
# Player Tkt bot 3 is placing pawn 4
#    Pawn placed at position (0, 4)
#
# Playing the game
#    Current pawn: pawn 1 of player 1 at position (2, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 2) and built at position (0, 1)
#
# 40 _0 20 _0 _0
# _0 _0 _0 _0 _0
# _0 10 _0 _0 _0
# _1 30 _0 _0 _0
# _0 _0 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (2, 4)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (1, 3) and built at position (0, 2)
#
# 40 _0 _0 _0 _0
# _0 20 _0 _0 _0
# _1 10 _0 _0 _0
# _1 30 _0 _0 _0
# _0 _0 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 0) and built at position (0, 1)
#
# 40 _0 _0 _0 _0
# _0 20 _0 _0 _0
# _1 10 _0 _0 _0
# _2 _0 _0 _0 _0
# 30 _0 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 4)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 40 20 _0 _0 _0
# _2 10 _0 _0 _0
# _2 _0 _0 _0 _0
# 30 _0 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 2)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (1, 1) and built at position (0, 1)
#
# _0 _0 _0 _0 _0
# 40 20 _0 _0 _0
# _2 _0 _0 _0 _0
# _3 10 _0 _0 _0
# 30 _0 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 3)
# Player Tkt bot 2 is moving pawn 2
# 5
#    Pawn moved at position (0, 4) and built at position (1, 3)
#
# 20 _0 _0 _0 _0
# 40 _1 _0 _0 _0
# _2 _0 _0 _0 _0
# _3 10 _0 _0 _0
# 30 _0 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 0)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (1, 0) and built at position (0, 0)
#
# 20 _0 _0 _0 _0
# 40 _1 _0 _0 _0
# _2 _0 _0 _0 _0
# _3 10 _0 _0 _0
# _1 30 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 3)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (1, 2) and built at position (0, 1)
#
# 20 _0 _0 _0 _0
# _0 _1 _0 _0 _0
# _2 40 _0 _0 _0
# _4 10 _0 _0 _0
# _1 30 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (0, 0) and built at position (1, 1)
#
# 20 _0 _0 _0 _0
# _0 _1 _0 _0 _0
# _2 40 _0 _0 _0
# _4 _1 _0 _0 _0
# 11 30 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 4)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (0, 3) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 20 _1 _0 _0 _0
# _3 40 _0 _0 _0
# _4 _1 _0 _0 _0
# 11 30 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 0)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (1, 1) and built at position (0, 2)
#
# _0 _0 _0 _0 _0
# 20 _1 _0 _0 _0
# _4 40 _0 _0 _0
# _4 31 _0 _0 _0
# 11 _0 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 2)
# Player Tkt bot 2 is moving pawn 4
# 6
#    Pawn moved at position (1, 3) and built at position (0, 4)
#
# _1 _0 _0 _0 _0
# 20 41 _0 _0 _0
# _4 _0 _0 _0 _0
# _4 31 _0 _0 _0
# 11 _0 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (0, 0)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (1, 0) and built at position (0, 0)
#
# _1 _0 _0 _0 _0
# 20 41 _0 _0 _0
# _4 _0 _0 _0 _0
# _4 31 _0 _0 _0
# _2 10 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (0, 3)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (1, 2) and built at position (0, 3)
#
# _1 _0 _0 _0 _0
# _1 41 _0 _0 _0
# _4 20 _0 _0 _0
# _4 31 _0 _0 _0
# _2 10 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 1)
# Player Tkt bot 3 is moving pawn 3
# 5
#    Pawn moved at position (0, 0) and built at position (1, 1)
#
# _1 _0 _0 _0 _0
# _1 41 _0 _0 _0
# _4 20 _0 _0 _0
# _4 _2 _0 _0 _0
# 32 10 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (1, 3)
# Player Tkt bot 2 is moving pawn 4
# 5
#    Pawn moved at position (0, 3) and built at position (0, 4)
#
# _2 _0 _0 _0 _0
# 41 _1 _0 _0 _0
# _4 20 _0 _0 _0
# _4 _2 _0 _0 _0
# 32 10 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (1, 0)
# Player Tkt bot 3 is moving pawn 1
# 6
#    Pawn moved at position (2, 1) and built at position (1, 1)
#
# _2 _0 _0 _0 _0
# 41 _1 _0 _0 _0
# _4 20 _0 _0 _0
# _4 _3 10 _0 _0
# 32 _0 _0 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (1, 2)
# Player Tkt bot 2 is moving pawn 2
# 6
#    Pawn moved at position (2, 2) and built at position (1, 1)
#
# _2 _0 _0 _0 _0
# 41 _1 _0 _0 _0
# _4 _0 20 _0 _0
# _4 _4 10 _0 _0
# 32 _0 _0 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (0, 0)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (1, 0) and built at position (0, 0)
#
# _2 _0 _0 _0 _0
# 41 _1 _0 _0 _0
# _4 _0 20 _0 _0
# _4 _4 10 _0 _0
# _3 30 _0 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 3)
# Player Tkt bot 2 is moving pawn 4
# 10
#    Pawn moved at position (0, 4) and built at position (0, 3)
#
# 42 _0 _0 _0 _0
# _2 _1 _0 _0 _0
# _4 _0 20 _0 _0
# _4 _4 10 _0 _0
# _3 30 _0 _0 _0
#
#    Current pawn: pawn 1 of player 1 at position (2, 1)
# Player Tkt bot 3 is moving pawn 1
# 5
#    Pawn moved at position (2, 0) and built at position (2, 1)
#
# 42 _0 _0 _0 _0
# _2 _1 _0 _0 _0
# _4 _0 20 _0 _0
# _4 _4 _1 _0 _0
# _3 30 10 _0 _0
#
#    Current pawn: pawn 2 of player 2 at position (2, 2)
# Player Tkt bot 2 is moving pawn 2
# 20
#    Pawn moved at position (1, 2) and built at position (0, 3)
#
# 42 _0 _0 _0 _0
# _3 _1 _0 _0 _0
# _4 20 _0 _0 _0
# _4 _4 _1 _0 _0
# _3 30 10 _0 _0
#
#    Current pawn: pawn 3 of player 1 at position (1, 0)
# Player Tkt bot 3 is moving pawn 3
# 6
#    Pawn moved at position (2, 1) and built at position (1, 0)
#
# 42 _0 _0 _0 _0
# _3 _1 _0 _0 _0
# _4 20 _0 _0 _0
# _4 _4 31 _0 _0
# _3 _1 10 _0 _0
#
#    Current pawn: pawn 4 of player 2 at position (0, 4)
# Player Tkt bot 2 is moving pawn 4
# 20
#    Pawn moved at position (0, 3) and built at position (0, 4)
#
# _2 _0 _0 _0 _0
# 43 _1 _0 _0 _0
# _4 20 _0 _0 _0
# _4 _4 31 _0 _0
# _3 _1 10 _0 _0
#
# Player Tkt bot 2 wins!
#
# Results:
# Player Tkt bot 3 won 33 times (47.14%)
# Player Tkt bot 2 won 37 times (52.86%)
# {'Tkt bot 3': 33, 'Tkt bot 2': 37}
